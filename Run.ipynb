# %%
from Calcu import *
from Render import *

# %%
pSat = np.array([-6471000,0])
vSat = np.array([0,-11000])
pMoon = np.array([384399000*np.cos(-np.pi/3),384399000*np.sin(-np.pi/3)])
vMoon = np.array([1022*np.cos(np.pi/6),1022*np.sin(np.pi/6)])

X0 = np.array([pSat,pMoon,vSat,vMoon])

Result,delt = Simulation(X0,200000,80)
print(len(Result))
VisualOrbit(Result,delt)
#ParameterTime(Result,delt,1)
# Out:
# 1600000

# %%
leng = len(Result)
print(leng)
for k in range(8):
    print(Result[leng-8+k])
print(Result[-1])
# Out:
# 1600000
# 86765288.1215989
# 598085553.582358
# -388462072.64994496
# -8641114.259647591
# -447.45764783077396
# 93.80477028765655
# 28.962528481476166
# -1010.6662583658094
# -1010.6662583658094

# %%
pSat = np.array([86765288.1215989,598085553.582358])
vSat = np.array([-447.45764783077396,93.80477028765655])
pMoon = np.array([-388462072.64994496,-8641114.259647591])
vMoon = np.array([28.962528481476166,-1010.6662583658094])

X0 = np.array([pSat,pMoon,vSat,vMoon])

Result,delt = Simulation(X0,100000,80)
print(len(Result))
VisualOrbit(Result,delt)
# Out:
# 800000

# %%
con = 13

def fun(x):
    newcon = con+2*x
    return newcon

con = fun(2)
con
# Out:
# 15
